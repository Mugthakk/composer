# %%
# %matplotlib inline


from keras.models import Model
from keras import backend as K
from keras.callbacks import TensorBoard, EarlyStopping
from keras.layers import LSTM, Dropout, Dense, BatchNormalization, Activation, Input, TimeDistributed
from keras.regularizers import l2
from keras.layers.advanced_activations import LeakyReLU, ELU, PReLU
from keras.optimizers import RMSprop, Adam, Adadelta, Adagrad
from keras.utils import to_categorical
import numpy as np
from time import time
from matplotlib import pyplot as plt
import random as rn
import tensorflow as tf
from assignment.helpers import datapreparation as prep

# Seed session
np.random.seed(123456)
rn.seed(123456)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=0,
                              inter_op_parallelism_threads=0)
from keras import backend as K
tf.set_random_seed(123456)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)
##

fs1_dirpath = "./assignment/datasets/training/piano_roll_fs1"
fs5_dirpath = "./assignment/datasets/training/piano_roll_fs5"


# Load initial data
datasets = prep.load_all_dataset(fs5_dirpath)
dataset_names = prep.load_all_dataset_names(fs5_dirpath)
unique_names = set()
for name in dataset_names: # Make sure the same names get the same encoding each run
    unique_names.add(name)
unique_names = list(unique_names)
name_to_int = dict([(unique_names[i], i) for i in range(len(unique_names))])
int_to_name = dict([(i, unique_names[i]) for i in range(len(unique_names))])
dataset_names = to_categorical([name_to_int[name] for name in dataset_names]) # one-hot encode the composers
datasets = [dataset[:, 1:] for dataset in datasets] # Remove the headers

# Setting initial parameters
dataset_id_names = dict(zip(np.arange(len(dataset_names)), dataset_names))
longest_song = max(datasets[i].shape[1] for i in range(len(datasets)))
sequence_length = 50
length = longest_song//sequence_length + 1
num_keys = len(datasets[0])
parts_per_song = int(longest_song/sequence_length)
composer_encoding_len=len(dataset_names[0]) # 4 composers

# Makes several datasets from this first one with differing intervals between to capture the "gaps" between two sequences
# Add each subsequence of each song with differing offsets ([0:10], [1:11], [2:12], ...) to retain information.
# Unable to implement stateful, so try to retain as much information between subsequences as possible. 
# Also a way of dataset augmentation (regularization) by increasing the size of the dataset

def transpose_and_label_more(dataset_names, datasets, num_keys):
    zs = []
    datasets_transposed = np.array([(datasets[i].T, dataset_names[i]) for i in range(len(datasets))])
    for song, composer in datasets_transposed:
        for offset in range(0, sequence_length, 10): # Consider dropping offset, and use stateful to retain this info!
            for i in range(0, len(song)//sequence_length-offset):
                x = song[offset+i*sequence_length:offset+(i+1)*sequence_length]
                if i == len(song)//sequence_length - (1 + offset): # Add the EOF marker if last seq of song
                    y = np.append(song[offset+i*sequence_length+1:offset+(i+1)*sequence_length], np.array([np.ones(num_keys)]), 0)
                else:
                    y = song[offset+i*sequence_length+1:offset+(i+1)*sequence_length+1]
                zs.append((x, y, composer))
    xs, ys, composers = [], [], []
    for x, y, composer in zs:
        xs.append(x)
        ys.append(y)
        composers.append(composer)
    return np.array(xs), np.array(ys), np.array(composers)

train_xs, train_ys, train_composers = transpose_and_label_more(dataset_names, datasets, num_keys)
print(train_ys.shape)
# Out:
# Using TensorFlow backend.
# (3342, 50, 128)

# %%
specialist_input = Input(shape=(composer_encoding_len,))
x = Dense(32, activation="relu")(specialist_input) # Change the activation function within as the sigmoid quickly saturates due to shape. It's ok as output though.
specialist_output_h = Dense(num_keys, activation="relu")(x)
specialist_output_c = Dropout(0.2)(specialist_output_h)

inputs = Input(shape=(sequence_length, num_keys))

# Units = units per timestep LSTM block, i.e. output dimensionality (128 here since input and output 128 keys)
lstm1 = LSTM(num_keys,
               activation='relu',
               return_sequences=True,
               name="lstm1")
lstm1_outputs = lstm1(inputs, initial_state=[specialist_output_h, specialist_output_c]) # [h = prev output, c = memory], h should be None

normalized1 = BatchNormalization()(lstm1_outputs)
dense1 = Dense(num_keys*2, activation="relu")(normalized1)

lstm2 = LSTM(num_keys,
               activation='relu',
               return_sequences=True)(dense1)

normalized2 = BatchNormalization()(lstm2)
outputs = TimeDistributed(Dense(num_keys, activation="sigmoid",
                               kernel_regularizer=regularizers.l2(0.01),
                               activity_regularizer=regularizers.l1(0.01))))(normalized2) 
# Sigmoid keeps the probabilities independent of each other, while softmax does not!
# kernel_regularizer = regulizer on weights
# activity_regularizer = regularizer on outputs aka activations

model = Model([inputs, specialist_input], outputs)

adam = Adam(lr=0.001, amsgrad=True) 
# Ends up in a point where gradients really small, denominator really small and then loss exploding
# v_t is based on the gradients at the current time step, and previous v_t, thus when gradient really small as well as v_t-1
# the update denominator (sqrt(v_t) + epsilon) is so small that explodes.
# AMSGrad maintains the maximum of all v_t until the present time step and uses this maximum value for normalizing
# the running average of the gradient instead of the current v_t as is done in regular Adam.

#model.save("./models/latest.h5f")

# %%
# Want to penalize each output node independantly. 
# Log Loss aka multi-class multi-label as sigmoid -> binary CE, as want probs to be considered independent of each other.
# Combo of sigmoid and crossentropy here log counteracts exp to reduce the saturation :)
model.compile(loss='binary_crossentropy',
              optimizer=adam, # consider changing this one for others
              metrics=['categorical_accuracy'])
print(model.summary())

tensorboard = TensorBoard(log_dir="./logs/{}".format(time()))
early_stop = EarlyStopping(monitor="val_loss", min_delta=0, patience=3, verbose=0, mode="auto")

print(train_xs.shape, train_composers.shape, train_ys.shape)
model.fit([train_xs, train_composers], train_ys,
          epochs=300, # Train harder more for more things was too bad train man :(
          batch_size=32,
          shuffle=True, # shuffle here but not when constructing set to be able to validate later on :)
          #callbacks=[tensorboard],
          )
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 4)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           160         input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          4224        dense_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 50, 128)      0
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# lstm1 (LSTM)                    (None, 50, 128)      131584      input_2[0][0]
#                                                                  dense_2[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 50, 128)      512         lstm1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 50, 128)      16512       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 50, 128)      131584      dense_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 50, 128)      512         lstm_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 50, 128)      16512       batch_normalization_2[0][0]
# ==================================================================================================
# Total params: 301,600
# Trainable params: 301,088
# Non-trainable params: 512
# __________________________________________________________________________________________________
# None
# (3342, 50, 128) (3342, 4) (3342, 50, 128)
# Epoch 1/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.5237 - categorical_accuracy: 0.0666A: 28s - loss: 0.7330 - cat - ETA: 5s - loss: 0.5993 - categorical_accuracy - ETA: 4s - loss: 0.5872 - ca - ETA: 1s - loss: 0.5466 - categorical_
# Epoch 2/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.1106 - categorical_accuracy: 0.1316A: 19s - loss: 0.1891 - categorical_accu  - ETA: 2s - loss: 0.1146 - cate
# Epoch 3/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0683 - categorical_accuracy: 0.1573A: 17s - loss: 0.0755 - categorical_accurac - ETA: 6s - loss: 0.0699 - categorical_ac - ETA: 5s - loss: 0.0698 - categorical_accuracy: 0. - ETA: 5s - ETA: 0s - loss: 0.0683 - categorical_accuracy:
# Epoch 4/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0598 - categorical_accuracy: 0.1739A: 12s - loss: 0.0613 - c - ETA: 8s - loss: 0.060
# Epoch 5/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0565 - categorical_accuracy: 0.1831A: 12s - loss: 0.0559 - categorical_accuracy: 0.18 - ETA:  - ETA: 0s - loss: 0.0565 - categorical_accuracy: 0.18
# Epoch 6/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0546 - categorical_accuracy: 0.1875A: 17s - loss: 0.0562 - categoric - ETA: 6s - loss: 0.0548 - cate - ETA: 3s - loss: 0.0546 - categorical_accuracy - ETA: 3s - loss: 0.054
# Epoch 7/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0534 - categorical_accuracy: 0.1922 7s - loss: 0.0533 - categorical_accu - ETA: 1s - loss: 0.0535 - categorical_accu
# Epoch 8/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0524 - categorical_accuracy: 0.1936
# Epoch 9/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0516 - categorical_accuracy: 0.1999 4s -
# Epoch 10/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0510 - categorical_accuracy: 0.1990
# Epoch 11/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0503 - categorical_accuracy: 0.2021A: 18s - l - ETA: 4s
# Epoch 12/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0496 - categorical_accuracy: 0.2040A: 14s - loss: 0.0480 - categorical_accuracy: 0.203 - ETA: 14s - loss: 0.0482 - categorical_accuracy: 0.204 - ETA: 14s - loss: 0.0482 - categorical_accura
# Epoch 13/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0491 - categorical_accuracy: 0.2072 1s - loss: 0.0490 - categorical_accu
# Epoch 14/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0484 - categorical_accuracy: 0.2085
# Epoch 15/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0480 - categorical_accuracy: 0.2103A: 16s
# Epoch 16/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0473 - categorical_accuracy: 0.2126
# Epoch 17/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0467 - categorical_accuracy: 0.2154
# Epoch 18/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0464 - categorical_accuracy: 0.2164A: 17s - loss: 0.0465 - c - ETA: 12s - loss: 0.0463 - categorical_ac - ETA: 9s - l
# Epoch 19/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0457 - categorical_accuracy: 0.2180
# Epoch 20/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0455 - categorical_accuracy: 0.2191
# Epoch 21/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0449 - categorical_accuracy: 0.2228
# Epoch 22/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0445 - categorical_accuracy: 0.2219
# Epoch 23/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0439 - categorical_accuracy: 0.2265
# Epoch 24/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0435 - categorical_accuracy: 0.2262
# Epoch 25/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0433 - categorical_accuracy: 0.2286
# Epoch 26/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0431 - categorical_accuracy: 0.2295A: 10s - loss: 0.0427 - categorical_acc
# Epoch 27/200
# 3342/3342 [==============================] - 22s 6ms/step - loss: 0.0426 - categorical_accuracy: 0.2290
# Epoch 28/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0420 - categorical_accuracy: 0.2326 4s - loss: 0
# Epoch 29/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0420 - categorical_accuracy: 0.2322
# Epoch 30/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0414 - categorical_accuracy: 0.2340
# Epoch 31/200
# 3342/3342 [==============================] - 25s 8ms/step - loss: 0.0409 - categorical_accuracy: 0.2366
# Epoch 32/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0412 - categorical_accuracy: 0.2349 1s - loss: 0.0411 - categorica
# Epoch 33/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0408 - categorical_accuracy: 0.2391
# Epoch 34/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.0401 - categorical_accuracy: 0.2392
# Epoch 35/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0397 - categorical_accuracy: 0.2411
# Epoch 36/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0394 - categorical_accuracy: 0.2420
# Epoch 37/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0394 - categorical_accuracy: 0.2432
# Epoch 38/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0391 - categorical_accuracy: 0.2433
# Epoch 39/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0387 - categorical_accuracy: 0.2458
# Epoch 40/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0382 - categorical_accuracy: 0.2490 3s - loss: 0
# Epoch 41/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0382 - categorical_accuracy: 0.2493 3s - loss: 0.0383 - ca
# Epoch 42/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0379 - categorical_accuracy: 0.2509
# Epoch 43/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0386 - categorical_accuracy: 0.2505
# Epoch 44/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.0380 - categorical_accuracy: 0.2525
# Epoch 45/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0375 - categorical_accuracy: 0.2539
# Epoch 46/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0372 - categorical_accuracy: 0.2562
# Epoch 47/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0368 - categorical_accuracy: 0.2583
# Epoch 48/200
# 3342/3342 [==============================] - 25s 8ms/step - loss: 0.0365 - categorical_accuracy: 0.2581
# Epoch 49/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.0366 - categorical_accuracy: 0.2586 0s - loss: 0.0366 - categorical_accuracy: 0.25
# Epoch 50/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0367 - categorical_accuracy: 0.2586
# Epoch 51/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0358 - categorical_accuracy: 0.2626
# Epoch 52/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0356 - categorical_accuracy: 0.2647
# Epoch 53/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0363 - categorical_accuracy: 0.2634
# Epoch 54/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0355 - categorical_accuracy: 0.2633
# Epoch 55/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0350 - categorical_accuracy: 0.2692
# Epoch 56/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0349 - categorical_accuracy: 0.2702
# Epoch 57/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0351 - categorical_accuracy: 0.2672
# Epoch 58/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0345 - categorical_accuracy: 0.2718
# Epoch 59/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.0352 - categorical_accuracy: 0.2694
# Epoch 60/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0350 - categorical_accuracy: 0.2729
# Epoch 61/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0346 - categorical_accuracy: 0.2730
# Epoch 62/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0342 - categorical_accuracy: 0.2751
# Epoch 63/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0340 - categorical_accuracy: 0.2746
# Epoch 64/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0334 - categorical_accuracy: 0.2785 0s - loss: 0.0334 - categorical_accuracy:
# Epoch 65/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0338 - categorical_accuracy: 0.2784 1s - loss: 0.0337 - categorical_ac
# Epoch 66/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0334 - categorical_accuracy: 0.2791
# Epoch 67/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0331 - categorical_accuracy: 0.2820
# Epoch 68/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.0329 - categorical_accuracy: 0.2817
# Epoch 69/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0327 - categorical_accuracy: 0.2822A: 14s - loss: 0.0329 - cat
# Epoch 70/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0325 - categorical_accuracy: 0.2835
# Epoch 71/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0324 - categorical_accuracy: 0.2854
# Epoch 72/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0326 - categorical_accuracy: 0.2847
# Epoch 73/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.0329 - categorical_accuracy: 0.2843
# Epoch 74/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0328 - categorical_accuracy: 0.2826
# Epoch 75/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0476 - categorical_accuracy: 0.2336
# Epoch 76/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0439 - categorical_accuracy: 0.2350 1s - loss: 0.0440 - categorical_accura
# Epoch 77/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0385 - categorical_accuracy: 0.2563
# Epoch 78/200
# 3342/3342 [==============================] - 29s 9ms/step - loss: 0.0362 - categorical_accuracy: 0.2695
# Epoch 79/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0349 - categorical_accuracy: 0.2757
# Epoch 80/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0340 - categorical_accuracy: 0.2780
# Epoch 81/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0339 - categorical_accuracy: 0.2796
# Epoch 82/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0333 - categorical_accuracy: 0.2823
# Epoch 83/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0327 - categorical_accuracy: 0.2854
# Epoch 84/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0326 - categorical_accuracy: 0.2857A: 16s - loss: 0.0326 - categorical_accuracy: 0. - ETA: 14s - loss:
# Epoch 85/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0323 - categorical_accuracy: 0.2859
# Epoch 86/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0319 - categorical_accuracy: 0.2867
# Epoch 87/200
# 3342/3342 [==============================] - 29s 9ms/step - loss: 0.0319 - categorical_accuracy: 0.2881
# Epoch 88/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0315 - categorical_accuracy: 0.2889
# Epoch 89/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0314 - categorical_accuracy: 0.2900
# Epoch 90/200
# 3342/3342 [==============================] - ETA: 0s - loss: 0.0311 - categorical_accuracy: 0.2927 ETA: 1s - loss: 0.0311 - categori - 21s 6ms/step - loss: 0.0311 - categorical_accuracy: 0.2929
# Epoch 91/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0309 - categorical_accuracy: 0.2936
# Epoch 92/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0308 - categorical_accuracy: 0.2941A: 17 - ETA: 3s - loss: 0
# Epoch 93/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0312 - categorical_accuracy: 0.2935
# Epoch 94/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.0307 - categorical_accuracy: 0.2939
# Epoch 95/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0341 - categorical_accuracy: 0.2821
# Epoch 96/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0339 - categorical_accuracy: 0.2811
# Epoch 97/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0317 - categorical_accuracy: 0.2923 4s - l
# Epoch 98/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0310 - categorical_accuracy: 0.2932
# Epoch 99/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.0307 - categorical_accuracy: 0.2954
# Epoch 100/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0302 - categorical_accuracy: 0.2983
# Epoch 101/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0300 - categorical_accuracy: 0.2998
# Epoch 102/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0298 - categorical_accuracy: 0.3000
# Epoch 103/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0299 - categorical_accuracy: 0.2995
# Epoch 104/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0297 - categorical_accuracy: 0.3000 1s - loss: 0.0297 - categorical_
# Epoch 105/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0294 - categorical_accuracy: 0.3019
# Epoch 106/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0292 - categorical_accuracy: 0.3029
# Epoch 107/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0298 - categorical_accuracy: 0.2990
# Epoch 108/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0297 - categorical_accuracy: 0.3007
# Epoch 109/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0302 - categorical_accuracy: 0.2999
# Epoch 110/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0294 - categorical_accuracy: 0.3056
# Epoch 111/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0293 - categorical_accuracy: 0.3029
# Epoch 112/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.0291 - categorical_accuracy: 0.3041
# Epoch 113/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0290 - categorical_accuracy: 0.3056
# Epoch 114/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0292 - categorical_accuracy: 0.3035A: 23s - loss: 0.0300 - cat
# Epoch 115/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0290 - categorical_accuracy: 0.3047
# Epoch 116/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0288 - categorical_accuracy: 0.3069
# Epoch 117/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0286 - categorical_accuracy: 0.3073
# Epoch 118/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0284 - categorical_accuracy: 0.3083
# Epoch 119/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0286 - categorical_accuracy: 0.3068 6s -
# Epoch 120/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0287 - categorical_accuracy: 0.3065
# Epoch 121/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0287 - categorical_accuracy: 0.3064 2s - loss: 0.0287 - categorica
# Epoch 122/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0286 - categorical_accuracy: 0.3068
# Epoch 123/200
# 3342/3342 [==============================] - 25s 8ms/step - loss: 0.0286 - categorical_accuracy: 0.3082
# Epoch 124/200
# 3342/3342 [==============================] - 25s 8ms/step - loss: 0.0281 - categorical_accuracy: 0.3115A: 1
# Epoch 125/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.0281 - categorical_accuracy: 0.3099A:
# Epoch 126/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0281 - categorical_accuracy: 0.3097
# Epoch 127/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0279 - categorical_accuracy: 0.3101
# Epoch 128/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0292 - categorical_accuracy: 0.3068
# Epoch 129/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0291 - categorical_accuracy: 0.3059
# Epoch 130/200
# 3342/3342 [==============================] - 28s 9ms/step - loss: 0.0294 - categorical_accuracy: 0.3070 5s - los
# Epoch 131/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0285 - categorical_accuracy: 0.3098
# Epoch 132/200
# 3342/3342 [==============================] - 28s 9ms/step - loss: 0.0279 - categorical_accuracy: 0.3119
# Epoch 133/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0277 - categorical_accuracy: 0.3122
# Epoch 134/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0273 - categorical_accuracy: 0.3147
# Epoch 135/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0275 - categorical_accuracy: 0.3141
# Epoch 136/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0272 - categorical_accuracy: 0.3157
# Epoch 137/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0270 - categorical_accuracy: 0.3152
# Epoch 138/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0278 - categorical_accuracy: 0.3132 5s -
# Epoch 139/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0280 - categorical_accuracy: 0.3117
# Epoch 140/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.0275 - categorical_accuracy: 0.3161 2s - loss: 0.0274 -
# Epoch 141/200
# 3342/3342 [==============================] - 28s 9ms/step - loss: 0.0273 - categorical_accuracy: 0.3155
# Epoch 142/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0276 - categorical_accuracy: 0.3163 3s - loss: 0
# Epoch 143/200
# 3342/3342 [==============================] - 28s 9ms/step - loss: 0.0268 - categorical_accuracy: 0.3186
# Epoch 144/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0271 - categorical_accuracy: 0.3175 1s - loss: 0.0272 - categorical_ac
# Epoch 145/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0271 - categorical_accuracy: 0.3156
# Epoch 146/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0267 - categorical_accuracy: 0.3180
# Epoch 147/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0266 - categorical_accuracy: 0.3195
# Epoch 148/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0264 - categorical_accuracy: 0.3187A: 17s - loss: 0.0259 - categ - ETA: 13s - loss: 0.0258 - categorical_ - ETA: 10s
# Epoch 149/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0265 - categorical_accuracy: 0.3200
# Epoch 150/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0263 - categorical_accuracy: 0.3212
# Epoch 151/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0265 - categorical_accuracy: 0.3205
# Epoch 152/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0273 - categorical_accuracy: 0.3173
# Epoch 153/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0265 - categorical_accuracy: 0.3186
# Epoch 154/200
# 3342/3342 [==============================] - 28s 9ms/step - loss: 0.0262 - categorical_accuracy: 0.3227
# Epoch 155/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0263 - categorical_accuracy: 0.3214
# Epoch 156/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0268 - categorical_accuracy: 0.3194
# Epoch 157/200
# 3342/3342 [==============================] - 22s 6ms/step - loss: 0.0267 - categorical_accuracy: 0.3213
# Epoch 158/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0267 - categorical_accuracy: 0.3187
# Epoch 159/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0260 - categorical_accuracy: 0.3227
# Epoch 160/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0258 - categorical_accuracy: 0.3261
# Epoch 161/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0258 - categorical_accuracy: 0.3240
# Epoch 162/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0260 - categorical_accuracy: 0.3231
# Epoch 163/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0258 - categorical_accuracy: 0.3236
# Epoch 164/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.0255 - categorical_accuracy: 0.3262
# Epoch 165/200
# 3342/3342 [==============================] - 28s 9ms/step - loss: 0.0265 - categorical_accuracy: 0.3215
# Epoch 166/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0260 - categorical_accuracy: 0.3222
# Epoch 167/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0263 - categorical_accuracy: 0.3219
# Epoch 168/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0259 - categorical_accuracy: 0.3266
# Epoch 169/200
# 3342/3342 [==============================] - 28s 8ms/step - loss: 0.0257 - categorical_accuracy: 0.3243 6s
# Epoch 170/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0256 - categorical_accuracy: 0.3261 2s - loss: 0.0257
# Epoch 171/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0253 - categorical_accuracy: 0.3285
# Epoch 172/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0254 - categorical_accuracy: 0.3272
# Epoch 173/200
# 3342/3342 [==============================] - 25s 8ms/step - loss: 0.0251 - categorical_accuracy: 0.3272A: 17s - lo
# Epoch 174/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0251 - categorical_accuracy: 0.3283
# Epoch 175/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0249 - categorical_accuracy: 0.3294
# Epoch 176/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0249 - categorical_accuracy: 0.3300
# Epoch 177/200
# 3342/3342 [==============================] - 22s 6ms/step - loss: 0.0248 - categorical_accuracy: 0.3295
# Epoch 178/200
# 3342/3342 [==============================] - 29s 9ms/step - loss: 0.0249 - categorical_accuracy: 0.3301 0s - loss: 0.0249 - categorical_accuracy:
# Epoch 179/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0254 - categorical_accuracy: 0.3270A: 14s - loss: 0.0246 - categ - ETA: 10s
# Epoch 180/200
# 3342/3342 [==============================] - 29s 9ms/step - loss: 0.0271 - categorical_accuracy: 0.3201
# Epoch 181/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0304 - categorical_accuracy: 0.3116
# Epoch 182/200
# 3342/3342 [==============================] - 28s 9ms/step - loss: 0.0280 - categorical_accuracy: 0.3162 0s - loss: 0.0280 - categorical_accuracy:
# Epoch 183/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0261 - categorical_accuracy: 0.3266
# Epoch 184/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0255 - categorical_accuracy: 0.3273 1s - loss: 0.0255 - categorical_
# Epoch 185/200
# 3342/3342 [==============================] - 24s 7ms/step - loss: 0.0253 - categorical_accuracy: 0.3317
# Epoch 186/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0250 - categorical_accuracy: 0.3298
# Epoch 187/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0253 - categorical_accuracy: 0.3305
# Epoch 188/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.0251 - categorical_accuracy: 0.3325
# Epoch 189/200
# 3342/3342 [==============================] - 29s 9ms/step - loss: 0.0249 - categorical_accuracy: 0.3313
# Epoch 190/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0249 - categorical_accuracy: 0.3317
# Epoch 191/200
# 3342/3342 [==============================] - 28s 9ms/step - loss: 0.0247 - categorical_accuracy: 0.3318
# Epoch 192/200
# 3342/3342 [==============================] - 21s 6ms/step - loss: 0.0243 - categorical_accuracy: 0.3329
# Epoch 193/200
# 3342/3342 [==============================] - 29s 9ms/step - loss: 0.0244 - categorical_accuracy: 0.3340
# Epoch 194/200
# 3342/3342 [==============================] - 22s 7ms/step - loss: 0.0242 - categorical_accuracy: 0.3345
# Epoch 195/200
# 3342/3342 [==============================] - 27s 8ms/step - loss: 0.0243 - categorical_accuracy: 0.3342
# Epoch 196/200
# 3342/3342 [==============================] - 23s 7ms/step - loss: 0.0248 - categorical_accuracy: 0.3318
# Epoch 197/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0251 - categorical_accuracy: 0.3316A: 12s - loss: 0.0253 - cate
# Epoch 198/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0245 - categorical_accuracy: 0.3346
# Epoch 199/200
# 3342/3342 [==============================] - 25s 7ms/step - loss: 0.0244 - categorical_accuracy: 0.3325A: 1
# Epoch 200/200
# 3342/3342 [==============================] - 26s 8ms/step - loss: 0.0246 - categorical_accuracy: 0.3347

# %%
a = model.predict([train_xs, train_composers], verbose=True)
maxes = [np.max(c) for c in a]
plt.hist(maxes)
plt.show()
plt.hist(a[:,-1])
plt.show()
b = np.max(a[1][-1])
plt.plot(a[1][-1])
plt.show()
prep.visualize_piano_roll(a[0].T, fs=5)
prep.visualize_piano_roll(train_xs[0].T, fs=5)
plt.plot(a[100][-1])
plt.show()
prep.visualize_piano_roll(a[100].T, fs=5)
prep.visualize_piano_roll(train_xs[100].T, fs=5)
plt.plot(a[200][-1])
plt.show()
prep.visualize_piano_roll(a[200].T, fs=5)
prep.visualize_piano_roll(train_xs[200].T, fs=5)
# Out:
# 3342/3342 [==============================] - 11s 3ms/step

# %%
model.save("./models/nostate_50_offset_10_specialist.h5f")
# Out:
# c:\users\hanak\venv\music\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'dense_2/Relu:0' shape=(?, 128) dtype=float32>, <tf.Tensor 'dropout_1/cond/Merge:0' shape=(?, 128) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '

# %%
def make_song_from_predict(model, initial_data, composer, limit):
    song = []
    keep_producing = True
    prev_data = initial_data
    while keep_producing and len(song) < limit:
        predictions = model.predict([np.array([prev_data]), composer])[0]
        labels = np.zeros(predictions[-1].shape)
        labels[predictions[-1]/np.max(predictions[-1])>0.75] = 1 # Threshold to consider the key as active, binarized based on this
        last_output = labels
        keep_producing = np.sum(last_output) != len(last_output)
        song.append(last_output)
        prev_data = np.append(prev_data[1:], [last_output], 0)
    return np.array(song)

initial_step = 543
steps = 10
song1 = make_song_from_predict(model, train_xs[initial_step], np.array([[1.0, 0.0, 0.0, 0.0]]), sequence_length*steps)
song2 = make_song_from_predict(model, train_xs[initial_step], np.array([[0.0, 1.0, 0.0, 0.0]]), sequence_length*steps)
song3 = make_song_from_predict(model, train_xs[initial_step], np.array([[0.0, 0.0, 1.0, 0.0]]), sequence_length*steps)
song4 = make_song_from_predict(model, train_xs[initial_step], np.array([[0.0, 0.0, 0.0, 1.0]]), sequence_length*steps)
prep.embed_play_v1(song1.T, fs=5)

# %%
prep.embed_play_v1(song2.T, fs=5)

# %%
prep.embed_play_v1(song3.T, fs=5)

# %%
prep.embed_play_v1(song4.T, fs=5)

# %%
prep.visualize_piano_roll(song1.T, fs=5)
prep.visualize_piano_roll(song2.T, fs=5)
prep.visualize_piano_roll(song3.T, fs=5)
prep.visualize_piano_roll(song4.T, fs=5)
